# %% [markdown]
# <a href="https://colab.research.google.com/github/farbouw/TM11001-example/blob/main/AIP_segm3_Unet250428v7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1: Deep learning for SegmentationAdvanced Image Processing (TM11005)
#
# Exercise from Lecture: CNNs and Unet for image segmentation
#
# @author: Muhammad Arif
#
#
# In this exercise, you will learn how to:
#    - Prepare your data to be used with a deep learning model.
#    - Write code to build a unet using the deep learning package Keras.
#    - Feed data to a deep network as unet and train it.
#    - Supervise the learning of the network and how to quantify it.
#
# ## **Handing in your answers**
# For each exercise, you have to hand in answers to questions, and
# for some also the code. Hence please only hand in two files in total
# for this exercise set:
#
# - Code.ipynb: a jupyter notebook containing all the code you are requested to hand in.
# - Answers.pdf: a text file with the answers to the
# questions (plots, text, ...).
#
# "NOTE: ONLY EXERCISE 5, 6 AND EXERCISE 7 WILL BE GRADED"
#
# ## Instruction:
# Read Carefully the full CoLab notebook as you move forward. It is important to understand all the steps. If you are in doubt do not hesitate to ask one of tutors.
# # Exercise description:
#
# Colab allows you to use a GPU for your computations , which is required for
# Neural network models.
#
# For this exercise we will use part of a public data set named PROSTATEX,
# this data set was used in a challange to classify prostate cancer tumor according to their  gleasons grade. However, for our learning purposes, we will use it
# to train a network that will learn how to do automatic prostate segmentation.
#
# If you want to know more details about this data set you can consult the
# following link
#
# https://wiki.cancerimagingarchive.net/display/Public/SPIE-AAPM-NCI+PROSTATEx+Challenges
#
# ## Description:
#
# The PROSTATEx Challenge ("SPIE-AAPM-NCI Prostate MR Classification Challenge”)
# focused on quantitative image analysis methods for the diagnostic classification
# of clinically significant prostate cancers and was held in conjunction with the
# 2017 SPIE Medical Imaging Symposium (see http://www.spie.org/PROSTATEx/).  PROSTATEx
# ran from November 21, 2016 to January 15, 2017, though a "live" version has also
# been established at https://prostatex.grand-challenge.org which serves as an ongoing
#  way for researchers to benchmark their performance for this task.

# %% [markdown]
# ## Install SimpleITK and donwload the data

# %%
# we install the packages needed for this practical
# !pip install SimpleITK

# We copy the data from a github repository. After runing this command, you will
# inside the tab on your left that some scripst and a folder named "processed".
# This folder contains the image data set organized by patient folder.
! git clone https://github.com/jveenland/TM11005_Unet.git

# Run this part only once.
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.12/dist-packages (2.5.5)
# fatal: destination path 'TM11005_Unet' already exists and is not an empty directory.

# %% [markdown]
# Import the following packages

# %%
# Import neccesary  packages for  the  exercise.
import glob
import os
import numpy as np
from sklearn.model_selection import ShuffleSplit
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %% [markdown]
# # Exercise 1 : Getting to Know your data
#
#    Let's get a feeling of the data first. If you check the patient's folder in "TM11005_Unet/processed/"
#    you will find two folders; images and their corresponding segmentation.
#    Each image correspond to a 2D prostate axial slice.
#
# - Use the SimpleITK package to load a prostate slice from any
#    patient and the segmentation belonging to that slice, preferably choose
#    for one of the slices of the middle section,for instance: if the
#    prostate has 14 slices, load slice 7 or one close to it.
# - Plot a figure with a size of 1x3 showing 3 following images:
#    - The t2 sequence
#    - The mask
#    - The segmentation overlay on the t2 / The segmentation contour (your choice)
#    - Hint: To show the overlay you may use any function learned during previou exercises. As suggestion , you may choose one of these atributes: pyplot.contour or modifying the color map argument from gray to plt.cm.viridis.

# %%
#Excercise 1  Getting to know the data
t2_ima= sitk.ReadImage('/content/TM11005_Unet/processed/ProstateX-0100/images/Px_ProstateX-0100_slice_7.nii')
t2_arr= sitk.GetArrayFromImage(t2_ima)

#code here to read segmentation of same patient and do the plotting
#Image of patient 0900 and convert it to an array for plotting
t2_ima_patient0090 =sitk.ReadImage('/content/TM11005_Unet/processed/ProstateX-0090/images/Px_ProstateX-0090_slice_6.nii')
t2_arr_patient0090 = sitk.GetArrayFromImage(t2_ima_patient0090)

#Segmentation of patient 0900 and convert it to an arrray for plotting
t2_mask_patient0090 = sitk.ReadImage('/content/TM11005_Unet/processed/ProstateX-0090/segmentations/Px_ProstateX-0090_slice_6.nii')
t2_arrmask_patient0090 = sitk.GetArrayFromImage(t2_mask_patient0090)

#Overlay of the segmentation onto the image, but not used in plotting this time, only the contour is used
t2_overlay = t2_arr_patient0090 *t2_arrmask_patient0090

#Plotting the T2 sequence, mask and overlay with the contour of the segmentation on the T2 sequence
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(t2_arr_patient0090, cmap='gray')
plt.title("The T2 sequence")
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(t2_arrmask_patient0090, cmap='gray')
plt.title("The mask")
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(t2_arr_patient0090, cmap='gray')
plt.contour(t2_arrmask_patient0090, colors='r')
plt.title("The overlay")
plt.axis('off')

plt.show()

# %% [markdown]
# ## Tutorial : improving how you load your data:
#
#    You may have noticed that the data is structured in a specific way. This last
# was done  not only with the objective to keep the data organized, but also to
# make the data proccessing with python easier. On the following example
# you will see how to get advantage of the directory names to locate the images
# for patient 100. In this case we are going to use the python module called
# "glob", Run the following lines, and understand what  the code is doing.

# %%
# First we define our patient (px) data folder
px       = 'ProstateX-0100'
px_fol   = '/content/TM11005_Unet/processed/'

# We define two variables to save the image and segmentation path.
# As you can see , glob list from a specific directory (px_fol) ,
# for a specific patient (px) , all the files (*) that ends as nifti format (nii.)
img_path = glob.glob(px_fol + '/'+px+'/images/*.nii')
seg_path = glob.glob(px_fol + '/'+px+'/segmentations/*.nii')

# Check what is contained in the two variables: img_path and seg_path
print(img_path)
print(seg_path)
# Out:
# ['/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_15.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_14.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_16.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_9.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_12.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_10.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_4.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_6.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_13.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_7.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_3.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_5.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_11.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_8.nii', '/content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_2.nii']
# ['/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_15.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_14.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_16.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_9.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_12.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_10.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_4.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_6.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_13.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_7.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_3.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_5.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_11.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_8.nii', '/content/TM11005_Unet/processed//ProstateX-0100/segmentations/Px_ProstateX-0100_slice_2.nii']

# %% [markdown]
# # Exercise 2  :  create patient_path_list function:
#   -  Write a function called create_px_path that takes a list of patients as input.
#   -The function should return  two lists. One list should contain the path
#     to the images and the other the paths to the segmentation files.
#   - IMPORTANT: check that the ordering inside the two list corresponds to the same image and segmentation. For instance, if the first element in the images list corresponds to patient 100 slice 8. Then,the first element of the segmentation list should correspond to patient 100, slice 8 as well.

# %%
from re import X
#Exercise 2
#Definition to create path for patient's image and segmentatio
def create_px_path(px_list):
  #Define data folder
  px_fol   = '/content/TM11005_Unet/processed/'
  #Empty lists fo saving the paths
  x_imag = []
  y_segm = []

  #Loop over all the patients in the list
  for px in px_list:
    #Search for all image and segmentation files (.nii) in the folders
    img_paths = glob.glob(px_fol + '/'+px+'/images/*.nii')
    seg_paths = glob.glob(px_fol + '/'+px+'/segmentations/*.nii')
    #Sort both the lists, such that image and mask remain together in the correct order
    img_paths.sort()
    seg_paths.sort()
    x_imag.extend(img_paths)
    y_segm.extend(seg_paths)
  return x_imag, y_segm

# %% [markdown]
# ## Check-point
#
# Run the following code to check the result of Exercise 2

# %%
# Check-POINT if you did the previous exercise correctly , this function should't
# give an error. IF you do get an error, you must go back and fix your code

def check_fun(x_path):

    samp_lis , _= create_px_path(x_path)
    print(samp_lis)
    if not samp_lis:
        raise('your create_px_path function is returning an empty list')

    for sam in samp_lis:
        print(sam)
        if isinstance(sam,list):
           raise('The output of your create_px_path function is wrong, it returns as output a list with more lists inside...')
    return


check_fun(os.listdir(px_fol))
# Out:
# ['/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_10.nii', '/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_11.nii', '/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_12.nii', '/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_13.nii', '/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_5.nii', '/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_6.nii', '/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_7.nii', '/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_8.nii', '/content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_9.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_0.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_1.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_10.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_11.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_12.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_13.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_14.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_15.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_3.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_4.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_5.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_6.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_7.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_8.nii', '/content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_9.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_10.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_11.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_12.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_13.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_4.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_5.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_6.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_7.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_8.nii', '/content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_9.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_10.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_11.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_12.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_13.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_14.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_15.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_3.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_4.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_5.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_6.nii', '/content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_7.nii', '/content/TM11005_U ...
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0000/images/Px_ProstateX-0000_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_0.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_1.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0082/images/Px_ProstateX-0082_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0048/images/Px_ProstateX-0048_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0035/images/Px_ProstateX-0035_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_1.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0098/images/Px_ProstateX-0098_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0121/images/Px_ProstateX-0121_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0092/images/Px_ProstateX-0092_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0040/images/Px_ProstateX-0040_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0104/images/Px_ProstateX-0104_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0084/images/Px_ProstateX-0084_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0136/images/Px_ProstateX-0136_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0078/images/Px_ProstateX-0078_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0087/images/Px_ProstateX-0087_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0033/images/Px_ProstateX-0033_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0114/images/Px_ProstateX-0114_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0106/images/Px_ProstateX-0106_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_18.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_19.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_20.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_21.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0039/images/Px_ProstateX-0039_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_18.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_19.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_20.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_21.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0120/images/Px_ProstateX-0120_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0109/images/Px_ProstateX-0109_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0115/images/Px_ProstateX-0115_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0099/images/Px_ProstateX-0099_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0034/images/Px_ProstateX-0034_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0090/images/Px_ProstateX-0090_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0100/images/Px_ProstateX-0100_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0102/images/Px_ProstateX-0102_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_18.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_19.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0085/images/Px_ProstateX-0085_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_18.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0027/images/Px_ProstateX-0027_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_18.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_19.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0081/images/Px_ProstateX-0081_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0030/images/Px_ProstateX-0030_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_18.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_19.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_20.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_21.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0042/images/Px_ProstateX-0042_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0044/images/Px_ProstateX-0044_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_18.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_19.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0050/images/Px_ProstateX-0050_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0026/images/Px_ProstateX-0026_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0086/images/Px_ProstateX-0086_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0041/images/Px_ProstateX-0041_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0110/images/Px_ProstateX-0110_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0094/images/Px_ProstateX-0094_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0111/images/Px_ProstateX-0111_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0111/images/Px_ProstateX-0111_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0111/images/Px_ProstateX-0111_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0111/images/Px_ProstateX-0111_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0111/images/Px_ProstateX-0111_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0111/images/Px_ProstateX-0111_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0111/images/Px_ProstateX-0111_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_0.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_1.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_16.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_17.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_18.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_19.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_20.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0045/images/Px_ProstateX-0045_slice_9.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_0.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_1.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_10.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_11.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_12.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_13.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_14.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_15.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_2.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_3.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_4.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_5.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_6.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_7.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_8.nii
# /content/TM11005_Unet/processed//ProstateX-0112/images/Px_ProstateX-0112_slice_9.nii

# %% [markdown]
# # Exercise 3 data Normalization:
# In order to reduce the data differences, let's perform a data normalization   using the following formula:
#
#          norm_imag = image - percentile_05 / (percentile_95 - percentile_5)
#
# - Define a percentile_norm function that takes an image array as
#      input and return the image data normalized using the previous formula.
#      The goal here is to set all the images intensities in the same range from
#      (0 to 1).
#      HINT
#      Read the np.percentile function documentation to know how to obtain the 90th
#      and 10th percentile with numpy.
#
#   -To check that your function is working properly, plot a 2x3 figure, the first row should contain 3 random prostate slices, the second row will      contain the sames images after being normalized.
# -Even the images intensities where modified in terms of their range, you shall see that they visually are still the same.
#
#      Foundation:
#      - The idea behind normalizing the data is related to the fact that a learning
#        algorithm (Unet in our case), will use the image intensities to create kernels
#        with features to learn the segmentation. If there are many differences between
#        images intensities, finding common kernels for all the images would be a
#        intensive task because the feature space will be too broad. Resulting in a long
#        learning process and decreasing the chances of reaching a global minimum.

# %%
np.random.seed(180)   #Do not modify this line , it is for reproducibility.

images,_ = create_px_path(os.listdir(px_fol))
def percentile_norm(datas):
    #Determine the 5th and 95th percentile
    x_95  = np.percentile(datas,95)
    x_05  = np.percentile(datas,5)
    #Substract x_05 such that x_05 = 0
    datas = datas - x_05
    #Divide by the range, such that x_95 = 1
    datas  /= (x_95 - x_05)

    return datas

# Code here
#Choose 3 random images
three_random_images = np.random.choice(images, 3, replace=False)
plt.figure(figsize=(12,4))
#Loop over the 3 random images
for i, image in enumerate(three_random_images):
  image_data = sitk.ReadImage(image)
  image_data_arr = sitk.GetArrayFromImage(image_data)
  #Normalize the image to range 0-1
  image_data_norm = percentile_norm(image_data_arr.copy())

  #Plot the image
  plt.subplot(2,3,i+1)
  plt.imshow(image_data_arr, cmap='gray')
  plt.title("The T2 sequence")
  plt.axis('off')

  #Plot the normalized image
  plt.subplot(2,3,i+4)
  plt.imshow(image_data_norm, cmap='gray')
  plt.title("The normalized T2 sequence")
  plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Tutorial: Splitting the data
#   In this part of the code we define a function that split our patient
#   data into training, validation and test. The function takes a list of patient
#   names and randomly split it. First into training and test, then the training
#   is split into training and validation. In each iteration we take 20% of the patient data. The function returns a data dictionary with the names of the patient on each set.

# %%
#https://medium.com/@shivamrawat_756/how-to-prevent-google-colab-from-disconnecting-717b88a128c0

def split_data_train_val_test(px_fol):

    patients = os.listdir(px_fol)
    patients = np.asarray(patients)

    ss    = ShuffleSplit(n_splits=1,test_size=0.20)
    ss.get_n_splits(patients)
    for train_index, test_index in ss.split(patients):
        xt, x_test = patients[train_index], patients[test_index]

    ss = ShuffleSplit(n_splits=1, test_size=0.20)
    ss.get_n_splits(xt)
    for ten_index, val_index in ss.split(xt):
        x_train_in, x_val_in= xt[ten_index], xt[val_index]

    px_splits = {'train': np.ndarray.tolist(x_train_in),
                 'val'  : np.ndarray.tolist(x_val_in)  ,
                 'test' : np.ndarray.tolist(x_test)    }

    return px_splits

px_fol_path = '/content/TM11005_Unet/processed/'
px_split_di = split_data_train_val_test(px_fol_path)

# %% [markdown]
# # Exercise 4:
#    While training the network, we will need to provide the patients data paths.
#    Therefore, we need to obtain the path to each patient and their images.
#
#    - Use your create_px_path function from exercise 2 to generate the paths of each set.
#    - You will have to provide an image dictionary per set (x_train/val/test) and a segmentation dictionary (y_train /val /test).
#    - We use the x and y as a convention in machine learning for training data (x) and target/label data
#    (y).

# %%
#Create the train, validation and test sets using create_px_path returning the patient split dictionary
x_train , y_train = create_px_path(px_split_di['train'])
x_valid , y_valid = create_px_path(px_split_di['val'])
x_test  , y_test  = create_px_path(px_split_di['test'])

# %% [markdown]
# ##     Tutorial: Batch generator
#
#   These functions allow us to create a batch of data that is going to be
#     feeaded to Unet , one for the images and other for the segmentations. The
#     only difference is the noramlization for the t2 images, which is not
#     required for the segmentation image.

# %%
""" DO NOT MODIFY """
def generate_batch_norm(batch):
    data = []

    for img in batch:
        #print('img = '+str(img))
        img_data = sitk.ReadImage(img)

        img_data = sitk.GetArrayFromImage(img_data)
        img_data = img_data.astype('float32')
        img_data = percentile_norm(img_data)
        data.append(img_data)

    data = np.stack(data)


    data = np.reshape(data, (data.shape[0],data.shape[2],data.shape[1],1))
    return data

def generate_batch(batch):
    data = []

    for img in batch:
        #print('img = '+str(img))
        img_data = sitk.ReadImage(img)

        img_data = sitk.GetArrayFromImage(img_data)
        img_data = img_data.astype('float32')
        data.append(img_data)

    data = np.stack(data)


    data = np.reshape(data, (data.shape[0],data.shape[2],data.shape[1],1))
    return data

# %% [markdown]
#   ## Tutorial Data Generator
# Example Data generator: This function is made to generate a image batch. Neural networks consume a lot
#    of computing resources, therefore to train a network like U-net we feed it with
#    smaller portions of data, a data batch. This function takes a list of patient
#    image paths , image targets and the desired batch size. As you can see, the
#    end of the function finish with the word "yield" instead of return. This means
#    that the local variables will be kept while the condition of the function is
#    true, this kind of statement is used to return intermediate results.
#    In other words, we can keep "feeding" the Unet with data continuously, by providing
#    data batches until we reach to the end of the image list (while
#    the function is called by the network).

# %%
"""DO NOT MODIFY

"""
def data_feeder(x_lis,y_tar,d_size):
    while True:
        len_lis = len(x_lis)
        nu_part = int(np.ceil(len_lis / d_size))
        count   = 0

        for i in range(nu_part):

            current_batch_size = min(d_size, len_lis - count)

            p_list  = x_lis[count:count + current_batch_size]
            segment = y_tar[count:count + current_batch_size]

            images = generate_batch_norm(p_list)
            target = generate_batch(segment)
            count += current_batch_size
            if images.shape[0] == d_size:
                yield images, target

# %% [markdown]
#  ##  Dice coefficient formula:
#    To compute the error during learning process we will use the dice
#    coefficient. Every time the network performs a prediction (y_pred = segmentation prediction),
#    this new predicted image will be compared with the ground truth (y_true). Then,
#    based on this error value, the network will update its parameters in order to improve
#    the prediction for the next time it sees a new example. This process occurs mathematically
#    using differential equations. Therefore, we need define the dice function using tensors,
#    which allow us to compute the derivatives in python.

# %%
"""DO NOT MODIFY
"""
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred):
    y_true_f = tf.reshape(y_true,[-1])
    y_pred_f = tf.reshape(y_pred,[-1])
    intersection = K.sum(y_true_f * y_pred_f)
   # K.print_tensor(intersection, message="Dice intersection:")
    return -((2. * intersection + K.epsilon()) / (K.sum(y_true_f)
                                                  + K.sum(y_pred_f)
                                                  + K.epsilon()))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# # Exercise 5:  Define Unet using keras:
#
# On this part you will have to complete the code to  define unet. Given that the original unet request many computational resources, we will define a slightly simpler unet. As you can see most of the code is written already, you will need to use the image provided for this practical **model_exercise.png**
#    to complete the code.
#   - The parts that specifically requires your input are marked like this:
#    'x,x '.
#
#   - Define the input layer according to your image size and color channels    (height, width, channels)
#
#   - For the convolution layers  you must define ONLY
#      the number of kernels and a kernel  size =  3. The size of input
#      and output is taken care by tensorflow and keras.
#
#   - Define the Max pooling layers using a pooling of 2x2
#
#   - For the upsampling layers you will need a kernel size = 2.
#
#
#   - Notice that the number of kernels is doubled on each convoultional layer
#      while the kernel size is kept the same.
#
#   - HINT: you may use keras documentation to help you with the code:
#        https://keras.io/layers/convolutional/
#
#   - When the model is finished, run the line create_unet.

# %%
print(generate_batch_norm(x_train[:1]).shape)
# Out:
# (1, 192, 192, 1)

# %%
# !pip install Keras-Preprocessing

# !pip install Keras-Preprocessing
import tensorflow as tf
from keras import Input
from keras.models import Model
from keras.layers import MaxPooling2D, UpSampling2D, Dropout
from tensorflow.keras.optimizers import Adam
from keras.layers import Concatenate, Conv2D
from keras_preprocessing.image import array_to_img
from keras.callbacks import ModelCheckpoint

# import tensorflow.compat.v1 as tf
# tf.disable_v2_behavior()
# from tf.keras.utils import plot_model

def create_unet():

    # Create a U-Net

    print('Creating U-Net...')

    #First, we have to provide the dimensions of the input images
    #This is (192,192,1), because I printed the shape in the cell above and it was (1,192,192,1). The first 1 means the batchsize, so the input is only (192,192,1). It is thus a grayscale image
    inputs = Input((192,192,1))

    #Here the encoder part begins
    #The first convolution layer: kernel size of 3, as given in the exercise, and it begins with 8 kernels so (8,2)
    conv1 = Conv2D(8,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(8,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1) #Pool size was given in the exercise (2,2), reducing the image size by 0.5


    print('conv1 shape:', conv1.shape)
    print('pool1 shape:', pool1.shape)

    #Second convolution layer: the number of kernels is doubled from 8 to 16 and the kernel size is still 3 as given in the exercise
    conv2 = Conv2D(16,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(16,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2) #Again the pool size was given in the exercise (2,2), reducing the image size by 0.5

    print('conv2 shape:', conv2.shape)
    print('pool2 shape:', pool2.shape)


    #Third convolution layer: the number of kernels is doubled again from 16 to 32 and the kernel size is still 3 as given in the exercise
    conv3 = Conv2D(32,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(32,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(conv3)
    drop4 = Dropout(0.5)(conv3)  # Added
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)  #Again the pool size was given in the exercise (2,2), reducing the image size by 0.5


    print('conv3 shape:', conv3.shape)
    print('pool3 shape:', pool3.shape)

    #Fourth convolution layer: the number of kernels is doubled again from 32 to 64 and the kernel size is still 3 as given in the exercise
    conv4 = Conv2D(64,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(64,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)

    print('conv4 shape:', conv4.shape)


    #Here the decoder part begins, upsampling increases the image size again
    #First upper convolution layer: the number of kernels is decreased from 64 to 32, kernel size is 2 for umsampling, as given in the exercise
    up7 = Conv2D(32,2 , activation='relu', padding='same',
                 kernel_initializer='he_normal')(
                         UpSampling2D(size=(2, 2))(drop4))  # Changed
    merge7 = Concatenate(axis=3)([conv3, up7])
    #Convolutional block after the skip connection. The number of kernels is still 32, but kernel size is now 3.
    conv7 = Conv2D(32,3 ,activation='relu', padding='same',
                   kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(32,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(conv7)
    print('conv7 shape:', conv7.shape)

    #Second upper convolution layer: the number of kernels is decreased from 32 to 16, kernel size is 2 for umsampling, as given in the exercise
    up8 = Conv2D(16,2 , activation='relu', padding='same',
                 kernel_initializer='he_normal')(
                         UpSampling2D(size=(2, 2))(conv7))
    merge8 = Concatenate(axis=3)([conv2, up8])
    #Convolutional block after the skip connection. The number of kernels is still 16, but kernel size is now 3.
    conv8 = Conv2D(16,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(16,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(conv8)
    print('conv8 shape:', conv8.shape)

    #Third upper convolution layer: the number of kernels is decreased from 16 to 8, kernel size is 2 for umsampling, as given in the exercise
    up9 = Conv2D(8,2 , activation='relu', padding='same',
                 kernel_initializer='he_normal')(
                         UpSampling2D(size=(2, 2))(conv8))
    merge9 = Concatenate(axis=3)([conv1, up9])
    #Convolutional block after the skip connection. The number of kernels is still 8 , but kernel size is now 3.
    conv9 = Conv2D(8,3 ,activation='relu', padding='same',
                   kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(8,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(conv9)
    conv9 = Conv2D(2,3 , activation='relu', padding='same',
                   kernel_initializer='he_normal')(conv9)
    print('conv9 shape:', conv9.shape)

    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)
    print('conv10 shape:', conv10.shape)

    model = Model(inputs=inputs, outputs=conv10)

    model.compile(optimizer='adam',
                  loss=dice_coef, metrics=[dice_coef_loss])



    print('Got U-Net!')

    return model

model = create_unet()
# Out:
# Requirement already satisfied: Keras-Preprocessing in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from Keras-Preprocessing) (2.0.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Keras-Preprocessing) (1.17.0)
# Requirement already satisfied: Keras-Preprocessing in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from Keras-Preprocessing) (2.0.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Keras-Preprocessing) (1.17.0)
# Creating U-Net...
# conv1 shape: (None, 192, 192, 8)
# pool1 shape: (None, 96, 96, 8)
# conv2 shape: (None, 96, 96, 16)
# pool2 shape: (None, 48, 48, 16)
# conv3 shape: (None, 48, 48, 32)
# pool3 shape: (None, 24, 24, 32)
# conv4 shape: (None, 24, 24, 64)
# conv7 shape: (None, 48, 48, 32)
# conv8 shape: (None, 96, 96, 16)
# conv9 shape: (None, 192, 192, 2)
# conv10 shape: (None, 192, 192, 1)
# Got U-Net!

# %% [markdown]
# ## Tutorial : Training Unet
#
#
#    In this section we start training Unet. First we define a number of epochs,
#    which is  the number of times that Unet is going to "observe"
#    the whole training set, and learn from it the features to perform the segmentation.
#    We also define a batch size of 4, which is the number of samples the network
#    is going to "see" at the same time. The bigger the number of batches, less
#    time will take the network to complete an epoch. However, as the number
#    of batches is increased, more RAM is required.

# %%
epch = 80
batch_size = 4

#Here we define where to save the network parameters (weights)
filepath='/content/TM11005_Unet/weights_nw/w_epoch_.{epoch:03d}_'+'.keras'

# To keep track of the learning process we use checkpoints, as you see in the
  #  code, every 15 epochs we are going to save the parameters of the network(weights).
  #  Therefore, we can restart the network on a earlier stage to compare the
  #  performance with the latest ones. This function is also useful in order
  #  to make a saving point in case our code fails, you can restart the training from
  #  one of this checkpoints, so the network doesn't need to start learning
  #  from the beginning.


  #  IMPORTAN WARNING: WHEN YOU START RUNNING THIS SECTION

  #  When the model training is finished, we are going to plot the training
  #  history in the following section.

#We define our check point based on the dice_coef_loss and check it every 5 epochs

checkpoint = ModelCheckpoint(filepath, monitor='val_dice_coef_loss',save_freq=83*5, verbose=1, save_best_only=False,
                              mode='max')

callbacks_list = [checkpoint]

  #  Keras package allow us to train the model using the attribute "fit_generator",
  #  we give as input the data generator previously defined, we also define what
  #  data is going to be used for training and validation. In history we are going
  #  to save all the training process.


  #     Run this part of the code, each epoch should take approximately 3-6 seconds,
  #  the code will run for 250 epochs. Therefore, you can take this tame to have a
  #  short coffee brake. After the training is complete, continue with the next
  #  section.

train_dataset = tf.data.Dataset.from_generator(
    lambda: data_feeder(x_train, y_train, batch_size),
    (tf.float32, tf.float32),
    (tf.TensorShape([batch_size, 192, 192, 1]), tf.TensorShape([batch_size, 192, 192, 1]))
)

validation_dataset = tf.data.Dataset.from_generator(
    lambda: data_feeder(x_valid, y_valid, batch_size),
    (tf.float32, tf.float32),
    (tf.TensorShape([batch_size, 192, 192, 1]), tf.TensorShape([batch_size, 192, 192, 1]))
)

history=model.fit(
    train_dataset,
    steps_per_epoch=len(x_train) // batch_size,
    epochs=epch,
    validation_data=validation_dataset,
    validation_steps=len(x_valid) // batch_size,
    callbacks=callbacks_list
)

# WARNING ....IMPORTANT......WARNING:

#     Colab after some minutes of inactivity will erase your session. Therefore,
#     all the data, and the weights generated by the network during the training
#     will be removed. To avoid losing your progress, you can run the code below, this will
#     start  downloading the files obtained during your exercise,
#     save them in your local drive.
#

import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from google.colab import files
import shutil

pd.to_pickle(history,'/content/TM11005_Unet/epochs_history')
files.download('/content/TM11005_Unet/epochs_history')

#Save and download all model weights

shutil.make_archive(
    '/content/weights_backup',
    'zip',
    '/content/TM11005_Unet/weights_nw'
)

files.download('/content/weights_backup.zip')
# Out:
# Epoch 1/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 23s 45ms/step - dice_coef_loss: 0.3293 - loss: -0.3293 - val_dice_coef_loss: 0.3711 - val_loss: -0.3711
# Epoch 2/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - dice_coef_loss: 0.3835 - loss: -0.3835 - val_dice_coef_loss: 0.3917 - val_loss: -0.3917
# Epoch 3/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - dice_coef_loss: 0.4079 - loss: -0.4079 - val_dice_coef_loss: 0.4080 - val_loss: -0.4080
# Epoch 4/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - dice_coef_loss: 0.4246 - loss: -0.4246 - val_dice_coef_loss: 0.4024 - val_loss: -0.4024
# Epoch 5/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - dice_coef_loss: 0.4378 - loss: -0.4378 - val_dice_coef_loss: 0.4294 - val_loss: -0.4294
# Epoch 6/80
# 12/80 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - dice_coef_loss: 0.4262 - loss: -0.4262
# Epoch 6: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.006_.keras
#
# Epoch 6: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.006_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - dice_coef_loss: 0.4484 - loss: -0.4484 - val_dice_coef_loss: 0.4329 - val_loss: -0.4329
# Epoch 7/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - dice_coef_loss: 0.4577 - loss: -0.4577 - val_dice_coef_loss: 0.4427 - val_loss: -0.4427
# Epoch 8/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - dice_coef_loss: 0.4670 - loss: -0.4670 - val_dice_coef_loss: 0.4540 - val_loss: -0.4540
# Epoch 9/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.4762 - loss: -0.4762 - val_dice_coef_loss: 0.4652 - val_loss: -0.4652
# Epoch 10/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.4867 - loss: -0.4867 - val_dice_coef_loss: 0.4735 - val_loss: -0.4735
# Epoch 11/80
# 27/80 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - dice_coef_loss: 0.4796 - loss: -0.4796
# Epoch 11: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.011_.keras
#
# Epoch 11: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.011_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.4937 - loss: -0.4937 - val_dice_coef_loss: 0.4732 - val_loss: -0.4732
# Epoch 12/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.5023 - loss: -0.5023 - val_dice_coef_loss: 0.4747 - val_loss: -0.4747
# Epoch 13/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - dice_coef_loss: 0.5125 - loss: -0.5125 - val_dice_coef_loss: 0.4930 - val_loss: -0.4930
# Epoch 14/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.5242 - loss: -0.5242 - val_dice_coef_loss: 0.5022 - val_loss: -0.5022
# Epoch 15/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - dice_coef_loss: 0.5328 - loss: -0.5328 - val_dice_coef_loss: 0.5121 - val_loss: -0.5121
# Epoch 16/80
# 43/80 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - dice_coef_loss: 0.5245 - loss: -0.5245
# Epoch 16: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.016_.keras
#
# Epoch 16: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.016_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - dice_coef_loss: 0.5387 - loss: -0.5387 - val_dice_coef_loss: 0.5237 - val_loss: -0.5237
# Epoch 17/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.5439 - loss: -0.5439 - val_dice_coef_loss: 0.5148 - val_loss: -0.5148
# Epoch 18/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - dice_coef_loss: 0.5584 - loss: -0.5584 - val_dice_coef_loss: 0.5337 - val_loss: -0.5337
# Epoch 19/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.5617 - loss: -0.5617 - val_dice_coef_loss: 0.5390 - val_loss: -0.5390
# Epoch 20/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.5782 - loss: -0.5782 - val_dice_coef_loss: 0.5413 - val_loss: -0.5413
# Epoch 21/80
# 59/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dice_coef_loss: 0.5749 - loss: -0.5749
# Epoch 21: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.021_.keras
#
# Epoch 21: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.021_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.5917 - loss: -0.5917 - val_dice_coef_loss: 0.5574 - val_loss: -0.5574
# Epoch 22/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.5987 - loss: -0.5987 - val_dice_coef_loss: 0.5757 - val_loss: -0.5757
# Epoch 23/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.6069 - loss: -0.6069 - val_dice_coef_loss: 0.5802 - val_loss: -0.5802
# Epoch 24/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - dice_coef_loss: 0.6108 - loss: -0.6108 - val_dice_coef_loss: 0.5887 - val_loss: -0.5887
# Epoch 25/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6217 - loss: -0.6217 - val_dice_coef_loss: 0.5808 - val_loss: -0.5808
# Epoch 26/80
# 74/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dice_coef_loss: 0.6200 - loss: -0.6200
# Epoch 26: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.026_.keras
#
# Epoch 26: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.026_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - dice_coef_loss: 0.6309 - loss: -0.6309 - val_dice_coef_loss: 0.6011 - val_loss: -0.6011
# Epoch 27/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.6345 - loss: -0.6345 - val_dice_coef_loss: 0.6065 - val_loss: -0.6065
# Epoch 28/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.6379 - loss: -0.6379 - val_dice_coef_loss: 0.6200 - val_loss: -0.6200
# Epoch 29/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - dice_coef_loss: 0.6557 - loss: -0.6557 - val_dice_coef_loss: 0.6330 - val_loss: -0.6330
# Epoch 30/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - dice_coef_loss: 0.6633 - loss: -0.6633 - val_dice_coef_loss: 0.6404 - val_loss: -0.6404
# Epoch 31/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - dice_coef_loss: 0.6660 - loss: -0.6660 - val_dice_coef_loss: 0.6420 - val_loss: -0.6420
# Epoch 32/80
#  8/80 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - dice_coef_loss: 0.6136 - loss: -0.6136
# Epoch 32: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.032_.keras
#
# Epoch 32: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.032_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - dice_coef_loss: 0.6761 - loss: -0.6761 - val_dice_coef_loss: 0.6351 - val_loss: -0.6351
# Epoch 33/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.6823 - loss: -0.6823 - val_dice_coef_loss: 0.6172 - val_loss: -0.6172
# Epoch 34/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - dice_coef_loss: 0.6933 - loss: -0.6933 - val_dice_coef_loss: 0.6705 - val_loss: -0.6705
# Epoch 35/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.7028 - loss: -0.7028 - val_dice_coef_loss: 0.6813 - val_loss: -0.6813
# Epoch 36/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.7140 - loss: -0.7140 - val_dice_coef_loss: 0.6307 - val_loss: -0.6307
# Epoch 37/80
# 24/80 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - dice_coef_loss: 0.6650 - loss: -0.6650
# Epoch 37: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.037_.keras
#
# Epoch 37: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.037_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.7078 - loss: -0.7078 - val_dice_coef_loss: 0.6764 - val_loss: -0.6764
# Epoch 38/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.7188 - loss: -0.7188 - val_dice_coef_loss: 0.6813 - val_loss: -0.6813
# Epoch 39/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.7242 - loss: -0.7242 - val_dice_coef_loss: 0.6962 - val_loss: -0.6962
# Epoch 40/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - dice_coef_loss: 0.7337 - loss: -0.7337 - val_dice_coef_loss: 0.6361 - val_loss: -0.6361
# Epoch 41/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.7425 - loss: -0.7425 - val_dice_coef_loss: 0.7153 - val_loss: -0.7153
# Epoch 42/80
# 39/80 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - dice_coef_loss: 0.7188 - loss: -0.7188
# Epoch 42: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.042_.keras
#
# Epoch 42: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.042_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.7442 - loss: -0.7442 - val_dice_coef_loss: 0.7353 - val_loss: -0.7353
# Epoch 43/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.7575 - loss: -0.7575 - val_dice_coef_loss: 0.7105 - val_loss: -0.7105
# Epoch 44/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - dice_coef_loss: 0.7544 - loss: -0.7544 - val_dice_coef_loss: 0.7267 - val_loss: -0.7267
# Epoch 45/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.7705 - loss: -0.7705 - val_dice_coef_loss: 0.7416 - val_loss: -0.7416
# Epoch 46/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.7725 - loss: -0.7725 - val_dice_coef_loss: 0.7090 - val_loss: -0.7090
# Epoch 47/80
# 52/80 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - dice_coef_loss: 0.7616 - loss: -0.7616
# Epoch 47: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.047_.keras
#
# Epoch 47: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.047_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.7833 - loss: -0.7833 - val_dice_coef_loss: 0.7465 - val_loss: -0.7465
# Epoch 48/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.7813 - loss: -0.7813 - val_dice_coef_loss: 0.7400 - val_loss: -0.7400
# Epoch 49/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.7890 - loss: -0.7890 - val_dice_coef_loss: 0.6841 - val_loss: -0.6841
# Epoch 50/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.7842 - loss: -0.7842 - val_dice_coef_loss: 0.7375 - val_loss: -0.7375
# Epoch 51/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - dice_coef_loss: 0.8003 - loss: -0.8003 - val_dice_coef_loss: 0.7740 - val_loss: -0.7740
# Epoch 52/80
# 68/80 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dice_coef_loss: 0.7901 - loss: -0.7901
# Epoch 52: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.052_.keras
#
# Epoch 52: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.052_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - dice_coef_loss: 0.8060 - loss: -0.8060 - val_dice_coef_loss: 0.7516 - val_loss: -0.7516
# Epoch 53/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.8099 - loss: -0.8099 - val_dice_coef_loss: 0.7688 - val_loss: -0.7688
# Epoch 54/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.8126 - loss: -0.8126 - val_dice_coef_loss: 0.7833 - val_loss: -0.7833
# Epoch 55/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.8160 - loss: -0.8160 - val_dice_coef_loss: 0.7829 - val_loss: -0.7829
# Epoch 56/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.8201 - loss: -0.8201 - val_dice_coef_loss: 0.7847 - val_loss: -0.7847
# Epoch 57/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - dice_coef_loss: 0.8302 - loss: -0.8302 - val_dice_coef_loss: 0.7956 - val_loss: -0.7956
# Epoch 58/80
#  4/80 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - dice_coef_loss: 0.8270 - loss: -0.8270
# Epoch 58: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.058_.keras
#
# Epoch 58: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.058_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.8264 - loss: -0.8264 - val_dice_coef_loss: 0.7910 - val_loss: -0.7910
# Epoch 59/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.8306 - loss: -0.8306 - val_dice_coef_loss: 0.7786 - val_loss: -0.7786
# Epoch 60/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.8347 - loss: -0.8347 - val_dice_coef_loss: 0.7832 - val_loss: -0.7832
# Epoch 61/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.8464 - loss: -0.8464 - val_dice_coef_loss: 0.7571 - val_loss: -0.7571
# Epoch 62/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - dice_coef_loss: 0.8476 - loss: -0.8476 - val_dice_coef_loss: 0.7783 - val_loss: -0.7783
# Epoch 63/80
# 18/80 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - dice_coef_loss: 0.8214 - loss: -0.8214
# Epoch 63: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.063_.keras
#
# Epoch 63: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.063_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - dice_coef_loss: 0.8448 - loss: -0.8448 - val_dice_coef_loss: 0.7914 - val_loss: -0.7914
# Epoch 64/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - dice_coef_loss: 0.8496 - loss: -0.8496 - val_dice_coef_loss: 0.7909 - val_loss: -0.7909
# Epoch 65/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.8489 - loss: -0.8489 - val_dice_coef_loss: 0.8071 - val_loss: -0.8071
# Epoch 66/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.8581 - loss: -0.8581 - val_dice_coef_loss: 0.7961 - val_loss: -0.7961
# Epoch 67/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.8552 - loss: -0.8552 - val_dice_coef_loss: 0.7922 - val_loss: -0.7922
# Epoch 68/80
# 33/80 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - dice_coef_loss: 0.8523 - loss: -0.8523
# Epoch 68: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.068_.keras
#
# Epoch 68: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.068_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - dice_coef_loss: 0.8654 - loss: -0.8654 - val_dice_coef_loss: 0.8094 - val_loss: -0.8094
# Epoch 69/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.8686 - loss: -0.8686 - val_dice_coef_loss: 0.8203 - val_loss: -0.8203
# Epoch 70/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.8677 - loss: -0.8677 - val_dice_coef_loss: 0.8017 - val_loss: -0.8017
# Epoch 71/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - dice_coef_loss: 0.8731 - loss: -0.8731 - val_dice_coef_loss: 0.8168 - val_loss: -0.8168
# Epoch 72/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.8728 - loss: -0.8728 - val_dice_coef_loss: 0.8229 - val_loss: -0.8229
# Epoch 73/80
# 47/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dice_coef_loss: 0.8671 - loss: -0.8671
# Epoch 73: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.073_.keras
#
# Epoch 73: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.073_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - dice_coef_loss: 0.8740 - loss: -0.8740 - val_dice_coef_loss: 0.8130 - val_loss: -0.8130
# Epoch 74/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.8767 - loss: -0.8767 - val_dice_coef_loss: 0.8249 - val_loss: -0.8249
# Epoch 75/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.8823 - loss: -0.8823 - val_dice_coef_loss: 0.8168 - val_loss: -0.8168
# Epoch 76/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.8872 - loss: -0.8872 - val_dice_coef_loss: 0.8266 - val_loss: -0.8266
# Epoch 77/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - dice_coef_loss: 0.8892 - loss: -0.8892 - val_dice_coef_loss: 0.8307 - val_loss: -0.8307
# Epoch 78/80
# 63/80 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dice_coef_loss: 0.8808 - loss: -0.8808
# Epoch 78: saving model to /content/TM11005_Unet/weights_nw/w_epoch_.078_.keras
#
# Epoch 78: finished saving model to /content/TM11005_Unet/weights_nw/w_epoch_.078_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - dice_coef_loss: 0.8839 - loss: -0.8839 - val_dice_coef_loss: 0.8086 - val_loss: -0.8086
# Epoch 79/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.8870 - loss: -0.8870 - val_dice_coef_loss: 0.8311 - val_loss: -0.8311
# Epoch 80/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.8914 - loss: -0.8914 - val_dice_coef_loss: 0.8182 - val_loss: -0.8182

# %%
from google.colab import files
files.download('/content/TM11005_Unet/epochs_history')

# %% [markdown]
# #   Plot your loss function graph

# %%
from datetime import datetime
now = datetime.now()
date_time = now.strftime("%m_%d_%Y_%H:%M:%S")
plt.figure(figsize=(16,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('/content/TM11005_Unet/model_loss_'+str(date_time)+'.png')
plt.show()

# %%
# Download your loss function graph#

from google.colab import files
files.download('/content/TM11005_Unet/model_loss_'+str(date_time)+'.png')

# %% [markdown]
# # Exercise 6: Explain the Loss Function
# Look at the graph, and answer the following
#
# - What is the relationship between the training loss and the validation loss?
#
# - How would you use this graph to decide until what point is reasonable to
#      train the network? and why?
#
# - How can you improve the validation loss and what parameters you can tune.
#
# Try those optimization steps and show your traning-validation loss curve.

# %%
#Changed the learning rate from 0.001 to 0.0001 to check if this changes the training-validation loss curve. A lower learning curve allows to make smaller updates in the weights
#Create a folder to save the weights from this experiment
os.makedirs('/content/TM11005_Unet/weights_nw_lr', exist_ok=True)

#Here we define where to save the network parameters (weights)
filepath = '/content/TM11005_Unet/weights_nw_lr/w_epoch_.{epoch:03d}_.keras'

#We define our check point based on the dice_coef_loss and check it every 5 epochs
checkpoint_lr = ModelCheckpoint(filepath,monitor='val_dice_coef_loss', save_freq=80*5, verbose=1, save_best_only=False, mode='max')

callbacks_list_lr = [checkpoint_lr]

epch = 80
batch_size = 4

#Create a new U-net model
model_lr = create_unet()

#Adam is used as the optimizer with now a learning rate of 0.0001
model_lr.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss=dice_coef, metrics=[dice_coef_loss])

train_dataset_lr = tf.data.Dataset.from_generator(
    lambda: data_feeder(x_train, y_train, batch_size),
    output_types=(tf.float32, tf.float32),
    output_shapes=(tf.TensorShape([batch_size, 192, 192, 1]), tf.TensorShape([batch_size, 192, 192, 1]))
)

validation_dataset_lr = tf.data.Dataset.from_generator(
    lambda: data_feeder(x_valid, y_valid, batch_size),
    output_types=(tf.float32, tf.float32),
    output_shapes=(tf.TensorShape([batch_size, 192, 192, 1]),tf.TensorShape([batch_size, 192, 192, 1]))
)

history_lr = model_lr.fit(
    train_dataset_lr,
    steps_per_epoch=len(x_train) // batch_size,
    epochs=epch,
    validation_data=validation_dataset_lr,
    validation_steps=len(x_valid) // batch_size,
    callbacks=callbacks_list_lr
)

plt.figure(figsize=(16,10))
plt.plot(history_lr.history['loss'])
plt.plot(history_lr.history['val_loss'])
plt.title('Model loss after optimisation')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

#Save and download all model weights
pd.to_pickle(history_lr.history, '/content/history_lr')
files.download('/content/history_lr')


shutil.make_archive(
    '/content/weights_lr0001',
    'zip',
    '/content/TM11005_Unet/weights_nw_lr'
)

files.download('/content/weights_lr0001.zip')
# Out:
# Creating U-Net...
# conv1 shape: (None, 192, 192, 8)
# pool1 shape: (None, 96, 96, 8)
# conv2 shape: (None, 96, 96, 16)
# pool2 shape: (None, 48, 48, 16)
# conv3 shape: (None, 48, 48, 32)
# pool3 shape: (None, 24, 24, 32)
# conv4 shape: (None, 24, 24, 64)
# conv7 shape: (None, 48, 48, 32)
# conv8 shape: (None, 96, 96, 16)
# conv9 shape: (None, 192, 192, 2)
# conv10 shape: (None, 192, 192, 1)
# Got U-Net!
# Epoch 1/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - dice_coef_loss: 0.2806 - loss: -0.2806 - val_dice_coef_loss: 0.3625 - val_loss: -0.3625
# Epoch 2/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - dice_coef_loss: 0.3883 - loss: -0.3883 - val_dice_coef_loss: 0.4099 - val_loss: -0.4099
# Epoch 3/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - dice_coef_loss: 0.4288 - loss: -0.4288 - val_dice_coef_loss: 0.4261 - val_loss: -0.4261
# Epoch 4/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - dice_coef_loss: 0.4521 - loss: -0.4521 - val_dice_coef_loss: 0.4400 - val_loss: -0.4400
# Epoch 5/80
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coef_loss: 0.4624 - loss: -0.4624
# Epoch 5: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.005_.keras
#
# Epoch 5: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.005_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - dice_coef_loss: 0.4711 - loss: -0.4711 - val_dice_coef_loss: 0.4458 - val_loss: -0.4458
# Epoch 6/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.4849 - loss: -0.4849 - val_dice_coef_loss: 0.4619 - val_loss: -0.4619
# Epoch 7/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.5010 - loss: -0.5010 - val_dice_coef_loss: 0.4699 - val_loss: -0.4699
# Epoch 8/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.5070 - loss: -0.5070 - val_dice_coef_loss: 0.4641 - val_loss: -0.4641
# Epoch 9/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - dice_coef_loss: 0.5105 - loss: -0.5105 - val_dice_coef_loss: 0.4805 - val_loss: -0.4805
# Epoch 10/80
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dice_coef_loss: 0.5119 - loss: -0.5119
# Epoch 10: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.010_.keras
#
# Epoch 10: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.010_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - dice_coef_loss: 0.5169 - loss: -0.5169 - val_dice_coef_loss: 0.4733 - val_loss: -0.4733
# Epoch 11/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.5200 - loss: -0.5200 - val_dice_coef_loss: 0.4856 - val_loss: -0.4856
# Epoch 12/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.5286 - loss: -0.5286 - val_dice_coef_loss: 0.4717 - val_loss: -0.4717
# Epoch 13/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.5336 - loss: -0.5336 - val_dice_coef_loss: 0.4890 - val_loss: -0.4890
# Epoch 14/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.5376 - loss: -0.5376 - val_dice_coef_loss: 0.4933 - val_loss: -0.4933
# Epoch 15/80
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dice_coef_loss: 0.5371 - loss: -0.5371
# Epoch 15: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.015_.keras
#
# Epoch 15: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.015_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - dice_coef_loss: 0.5453 - loss: -0.5453 - val_dice_coef_loss: 0.5002 - val_loss: -0.5002
# Epoch 16/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.5497 - loss: -0.5497 - val_dice_coef_loss: 0.5009 - val_loss: -0.5009
# Epoch 17/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.5550 - loss: -0.5550 - val_dice_coef_loss: 0.5073 - val_loss: -0.5073
# Epoch 18/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.5571 - loss: -0.5571 - val_dice_coef_loss: 0.5144 - val_loss: -0.5144
# Epoch 19/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.5614 - loss: -0.5614 - val_dice_coef_loss: 0.5159 - val_loss: -0.5159
# Epoch 20/80
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dice_coef_loss: 0.5564 - loss: -0.5564
# Epoch 20: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.020_.keras
#
# Epoch 20: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.020_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - dice_coef_loss: 0.5621 - loss: -0.5621 - val_dice_coef_loss: 0.5218 - val_loss: -0.5218
# Epoch 21/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.5674 - loss: -0.5674 - val_dice_coef_loss: 0.5309 - val_loss: -0.5309
# Epoch 22/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.5724 - loss: -0.5724 - val_dice_coef_loss: 0.5307 - val_loss: -0.5307
# Epoch 23/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.5691 - loss: -0.5691 - val_dice_coef_loss: 0.5305 - val_loss: -0.5305
# Epoch 24/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.5785 - loss: -0.5785 - val_dice_coef_loss: 0.5396 - val_loss: -0.5396
# Epoch 25/80
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dice_coef_loss: 0.5776 - loss: -0.5776
# Epoch 25: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.025_.keras
#
# Epoch 25: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.025_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - dice_coef_loss: 0.5798 - loss: -0.5798 - val_dice_coef_loss: 0.5365 - val_loss: -0.5365
# Epoch 26/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - dice_coef_loss: 0.5832 - loss: -0.5832 - val_dice_coef_loss: 0.5426 - val_loss: -0.5426
# Epoch 27/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.5879 - loss: -0.5879 - val_dice_coef_loss: 0.5428 - val_loss: -0.5428
# Epoch 28/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.5930 - loss: -0.5930 - val_dice_coef_loss: 0.5463 - val_loss: -0.5463
# Epoch 29/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.5934 - loss: -0.5934 - val_dice_coef_loss: 0.5457 - val_loss: -0.5457
# Epoch 30/80
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - dice_coef_loss: 0.5944 - loss: -0.5944
# Epoch 30: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.030_.keras
#
# Epoch 30: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.030_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.5956 - loss: -0.5956 - val_dice_coef_loss: 0.5568 - val_loss: -0.5568
# Epoch 31/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - dice_coef_loss: 0.5998 - loss: -0.5998 - val_dice_coef_loss: 0.5513 - val_loss: -0.5513
# Epoch 32/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - dice_coef_loss: 0.5959 - loss: -0.5959 - val_dice_coef_loss: 0.5488 - val_loss: -0.5488
# Epoch 33/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.5958 - loss: -0.5958 - val_dice_coef_loss: 0.5593 - val_loss: -0.5593
# Epoch 34/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.6067 - loss: -0.6067 - val_dice_coef_loss: 0.5572 - val_loss: -0.5572
# Epoch 35/80
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - dice_coef_loss: 0.6111 - loss: -0.6111
# Epoch 35: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.035_.keras
#
# Epoch 35: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.035_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6103 - loss: -0.6103 - val_dice_coef_loss: 0.5635 - val_loss: -0.5635
# Epoch 36/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - dice_coef_loss: 0.6125 - loss: -0.6125 - val_dice_coef_loss: 0.5574 - val_loss: -0.5574
# Epoch 37/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - dice_coef_loss: 0.6082 - loss: -0.6082 - val_dice_coef_loss: 0.5640 - val_loss: -0.5640
# Epoch 38/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.6173 - loss: -0.6173 - val_dice_coef_loss: 0.5711 - val_loss: -0.5711
# Epoch 39/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.6171 - loss: -0.6171 - val_dice_coef_loss: 0.5688 - val_loss: -0.5688
# Epoch 40/80
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - dice_coef_loss: 0.6148 - loss: -0.6148
# Epoch 40: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.040_.keras
#
# Epoch 40: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.040_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.6155 - loss: -0.6155 - val_dice_coef_loss: 0.5673 - val_loss: -0.5673
# Epoch 41/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.6202 - loss: -0.6202 - val_dice_coef_loss: 0.5684 - val_loss: -0.5684
# Epoch 42/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.6194 - loss: -0.6194 - val_dice_coef_loss: 0.5763 - val_loss: -0.5763
# Epoch 43/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.6266 - loss: -0.6266 - val_dice_coef_loss: 0.5763 - val_loss: -0.5763
# Epoch 44/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.6282 - loss: -0.6282 - val_dice_coef_loss: 0.5809 - val_loss: -0.5809
# Epoch 45/80
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - dice_coef_loss: 0.6305 - loss: -0.6305
# Epoch 45: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.045_.keras
#
# Epoch 45: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.045_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6319 - loss: -0.6319 - val_dice_coef_loss: 0.5741 - val_loss: -0.5741
# Epoch 46/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.6343 - loss: -0.6343 - val_dice_coef_loss: 0.5865 - val_loss: -0.5865
# Epoch 47/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - dice_coef_loss: 0.6393 - loss: -0.6393 - val_dice_coef_loss: 0.5823 - val_loss: -0.5823
# Epoch 48/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - dice_coef_loss: 0.6377 - loss: -0.6377 - val_dice_coef_loss: 0.5888 - val_loss: -0.5888
# Epoch 49/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6442 - loss: -0.6442 - val_dice_coef_loss: 0.5894 - val_loss: -0.5894
# Epoch 50/80
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dice_coef_loss: 0.6447 - loss: -0.6447
# Epoch 50: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.050_.keras
#
# Epoch 50: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.050_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - dice_coef_loss: 0.6453 - loss: -0.6453 - val_dice_coef_loss: 0.5875 - val_loss: -0.5875
# Epoch 51/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.6463 - loss: -0.6463 - val_dice_coef_loss: 0.5871 - val_loss: -0.5871
# Epoch 52/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.6474 - loss: -0.6474 - val_dice_coef_loss: 0.5926 - val_loss: -0.5926
# Epoch 53/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - dice_coef_loss: 0.6510 - loss: -0.6510 - val_dice_coef_loss: 0.5934 - val_loss: -0.5934
# Epoch 54/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.6535 - loss: -0.6535 - val_dice_coef_loss: 0.5920 - val_loss: -0.5920
# Epoch 55/80
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - dice_coef_loss: 0.6524 - loss: -0.6524
# Epoch 55: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.055_.keras
#
# Epoch 55: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.055_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - dice_coef_loss: 0.6538 - loss: -0.6538 - val_dice_coef_loss: 0.5790 - val_loss: -0.5790
# Epoch 56/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.6580 - loss: -0.6580 - val_dice_coef_loss: 0.6028 - val_loss: -0.6028
# Epoch 57/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6600 - loss: -0.6600 - val_dice_coef_loss: 0.5961 - val_loss: -0.5961
# Epoch 58/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6640 - loss: -0.6640 - val_dice_coef_loss: 0.6032 - val_loss: -0.6032
# Epoch 59/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - dice_coef_loss: 0.6683 - loss: -0.6683 - val_dice_coef_loss: 0.6028 - val_loss: -0.6028
# Epoch 60/80
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dice_coef_loss: 0.6692 - loss: -0.6692
# Epoch 60: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.060_.keras
#
# Epoch 60: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.060_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - dice_coef_loss: 0.6688 - loss: -0.6688 - val_dice_coef_loss: 0.6048 - val_loss: -0.6048
# Epoch 61/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dice_coef_loss: 0.6692 - loss: -0.6692 - val_dice_coef_loss: 0.5881 - val_loss: -0.5881
# Epoch 62/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6702 - loss: -0.6702 - val_dice_coef_loss: 0.6193 - val_loss: -0.6193
# Epoch 63/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6745 - loss: -0.6745 - val_dice_coef_loss: 0.6091 - val_loss: -0.6091
# Epoch 64/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - dice_coef_loss: 0.6758 - loss: -0.6758 - val_dice_coef_loss: 0.5968 - val_loss: -0.5968
# Epoch 65/80
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dice_coef_loss: 0.6787 - loss: -0.6787
# Epoch 65: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.065_.keras
#
# Epoch 65: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.065_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - dice_coef_loss: 0.6783 - loss: -0.6783 - val_dice_coef_loss: 0.6048 - val_loss: -0.6048
# Epoch 66/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - dice_coef_loss: 0.6806 - loss: -0.6806 - val_dice_coef_loss: 0.6122 - val_loss: -0.6122
# Epoch 67/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.6832 - loss: -0.6832 - val_dice_coef_loss: 0.6154 - val_loss: -0.6154
# Epoch 68/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.6845 - loss: -0.6845 - val_dice_coef_loss: 0.6209 - val_loss: -0.6209
# Epoch 69/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.6882 - loss: -0.6882 - val_dice_coef_loss: 0.6193 - val_loss: -0.6193
# Epoch 70/80
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dice_coef_loss: 0.6916 - loss: -0.6916
# Epoch 70: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.070_.keras
#
# Epoch 70: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.070_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - dice_coef_loss: 0.6895 - loss: -0.6895 - val_dice_coef_loss: 0.6217 - val_loss: -0.6217
# Epoch 71/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.6924 - loss: -0.6924 - val_dice_coef_loss: 0.6125 - val_loss: -0.6125
# Epoch 72/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.6937 - loss: -0.6937 - val_dice_coef_loss: 0.6190 - val_loss: -0.6190
# Epoch 73/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - dice_coef_loss: 0.6954 - loss: -0.6954 - val_dice_coef_loss: 0.6363 - val_loss: -0.6363
# Epoch 74/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.6963 - loss: -0.6963 - val_dice_coef_loss: 0.6340 - val_loss: -0.6340
# Epoch 75/80
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dice_coef_loss: 0.7018 - loss: -0.7018
# Epoch 75: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.075_.keras
#
# Epoch 75: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.075_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - dice_coef_loss: 0.6990 - loss: -0.6990 - val_dice_coef_loss: 0.6213 - val_loss: -0.6213
# Epoch 76/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dice_coef_loss: 0.6995 - loss: -0.6995 - val_dice_coef_loss: 0.6285 - val_loss: -0.6285
# Epoch 77/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - dice_coef_loss: 0.7028 - loss: -0.7028 - val_dice_coef_loss: 0.6214 - val_loss: -0.6214
# Epoch 78/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.7049 - loss: -0.7049 - val_dice_coef_loss: 0.6430 - val_loss: -0.6430
# Epoch 79/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - dice_coef_loss: 0.7071 - loss: -0.7071 - val_dice_coef_loss: 0.6452 - val_loss: -0.6452
# Epoch 80/80
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - dice_coef_loss: 0.7097 - loss: -0.7097
# Epoch 80: saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.080_.keras
#
# Epoch 80: finished saving model to /content/TM11005_Unet/weights_nw_lr/w_epoch_.080_.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - dice_coef_loss: 0.7080 - loss: -0.7080 - val_dice_coef_loss: 0.6400 - val_loss: -0.6400

# %%
#Second optimisation: change batch size from 4 to 2, while preserving the learning rate from above 0.0001
#Create a folder to save the weights from this experiment
os.makedirs('/content/TM11005_Unet/weights_bs2', exist_ok=True)

#Here we define where to save the network parameters (weights)
filepath_bs2 = '/content/TM11005_Unet/weights_bs2/w_epoch_.{epoch:03d}_.keras'

#Batch size is changed to 2 here
epch = 80
batch_size = 2

#We define our check point based on the dice_coef_loss and check it every 5 epochs
checkpoint_bs2 = ModelCheckpoint(filepath_bs2,monitor='val_dice_coef_loss', save_freq=160*5, verbose=1, save_best_only=False, mode='max')

callbacks_list_bs2 = [checkpoint_bs2]

model_bs2 = create_unet()

#Adam is used as the optimizer with now a learning rate of 0.0001
model_bs2.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss=dice_coef, metrics=[dice_coef_loss])

train_dataset_bs2 = tf.data.Dataset.from_generator(
    lambda: data_feeder(x_train, y_train, batch_size),
    output_types=(tf.float32, tf.float32),
    output_shapes=(tf.TensorShape([batch_size, 192, 192, 1]),tf.TensorShape([batch_size, 192, 192, 1]))
)

validation_dataset_bs2 = tf.data.Dataset.from_generator(
    lambda: data_feeder(x_valid, y_valid, batch_size),
    output_types=(tf.float32, tf.float32),
    output_shapes=(tf.TensorShape([batch_size, 192, 192, 1]),tf.TensorShape([batch_size, 192, 192, 1]))
)


history_bs2 = model_bs2.fit(
    train_dataset_bs2,
    steps_per_epoch=len(x_train) // batch_size,
    epochs=80,
    validation_data=validation_dataset_bs2,
    validation_steps=len(x_valid) // batch_size,
    callbacks=callbacks_list_bs2
)

plt.figure(figsize=(16,10))
plt.plot(history_bs2.history['loss'])
plt.plot(history_bs2.history['val_loss'])
plt.title('Model loss with learning rate 0.0001 and batch size 2')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

pd.to_pickle(history_bs2.history, '/content/history_bs2')
files.download('/content/history_bs2')

shutil.make_archive(
    '/content/weights_bs2',
    'zip',
    '/content/TM11005_Unet/weights_bs2'
)

files.download('/content/weights_bs2.zip')
# Out:
# Creating U-Net...
# conv1 shape: (None, 192, 192, 8)
# pool1 shape: (None, 96, 96, 8)
# conv2 shape: (None, 96, 96, 16)
# pool2 shape: (None, 48, 48, 16)
# conv3 shape: (None, 48, 48, 32)
# pool3 shape: (None, 24, 24, 32)
# conv4 shape: (None, 24, 24, 64)
# conv7 shape: (None, 48, 48, 32)
# conv8 shape: (None, 96, 96, 16)
# conv9 shape: (None, 192, 192, 2)
# conv10 shape: (None, 192, 192, 1)
# Got U-Net!
# Epoch 1/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - dice_coef_loss: 0.2763 - loss: -0.2763 - val_dice_coef_loss: 0.4084 - val_loss: -0.4084
# Epoch 2/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.4247 - loss: -0.4247 - val_dice_coef_loss: 0.4391 - val_loss: -0.4391
# Epoch 3/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.4700 - loss: -0.4700 - val_dice_coef_loss: 0.4376 - val_loss: -0.4376
# Epoch 4/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.4922 - loss: -0.4922 - val_dice_coef_loss: 0.4694 - val_loss: -0.4694
# Epoch 5/80
# 155/161 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - dice_coef_loss: 0.5128 - loss: -0.5128
# Epoch 5: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.005_.keras
#
# Epoch 5: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.005_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - dice_coef_loss: 0.5468 - loss: -0.5468 - val_dice_coef_loss: 0.6534 - val_loss: -0.6534
# Epoch 6/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - dice_coef_loss: 0.6737 - loss: -0.6737 - val_dice_coef_loss: 0.5680 - val_loss: -0.5680
# Epoch 7/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.7168 - loss: -0.7168 - val_dice_coef_loss: 0.6742 - val_loss: -0.6742
# Epoch 8/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.7266 - loss: -0.7266 - val_dice_coef_loss: 0.6688 - val_loss: -0.6688
# Epoch 9/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - dice_coef_loss: 0.7460 - loss: -0.7460 - val_dice_coef_loss: 0.6946 - val_loss: -0.6946
# Epoch 10/80
# 149/161 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - dice_coef_loss: 0.7262 - loss: -0.7262
# Epoch 10: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.010_.keras
#
# Epoch 10: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.010_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - dice_coef_loss: 0.7413 - loss: -0.7413 - val_dice_coef_loss: 0.6959 - val_loss: -0.6959
# Epoch 11/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.7483 - loss: -0.7483 - val_dice_coef_loss: 0.7093 - val_loss: -0.7093
# Epoch 12/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.7504 - loss: -0.7504 - val_dice_coef_loss: 0.7094 - val_loss: -0.7094
# Epoch 13/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.7552 - loss: -0.7552 - val_dice_coef_loss: 0.7223 - val_loss: -0.7223
# Epoch 14/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - dice_coef_loss: 0.7646 - loss: -0.7646 - val_dice_coef_loss: 0.7326 - val_loss: -0.7326
# Epoch 15/80
# 143/161 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - dice_coef_loss: 0.7700 - loss: -0.7700
# Epoch 15: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.015_.keras
#
# Epoch 15: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.015_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - dice_coef_loss: 0.7813 - loss: -0.7813 - val_dice_coef_loss: 0.7319 - val_loss: -0.7319
# Epoch 16/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.7800 - loss: -0.7800 - val_dice_coef_loss: 0.7376 - val_loss: -0.7376
# Epoch 17/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.7815 - loss: -0.7815 - val_dice_coef_loss: 0.7464 - val_loss: -0.7464
# Epoch 18/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.7967 - loss: -0.7967 - val_dice_coef_loss: 0.7449 - val_loss: -0.7449
# Epoch 19/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - dice_coef_loss: 0.7848 - loss: -0.7848 - val_dice_coef_loss: 0.7500 - val_loss: -0.7500
# Epoch 20/80
# 138/161 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - dice_coef_loss: 0.7920 - loss: -0.7920
# Epoch 20: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.020_.keras
#
# Epoch 20: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.020_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - dice_coef_loss: 0.8038 - loss: -0.8038 - val_dice_coef_loss: 0.7594 - val_loss: -0.7594
# Epoch 21/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8141 - loss: -0.8141 - val_dice_coef_loss: 0.7586 - val_loss: -0.7586
# Epoch 22/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8169 - loss: -0.8169 - val_dice_coef_loss: 0.7557 - val_loss: -0.7557
# Epoch 23/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8205 - loss: -0.8205 - val_dice_coef_loss: 0.7621 - val_loss: -0.7621
# Epoch 24/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - dice_coef_loss: 0.8282 - loss: -0.8282 - val_dice_coef_loss: 0.7747 - val_loss: -0.7747
# Epoch 25/80
# 132/161 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - dice_coef_loss: 0.8275 - loss: -0.8275
# Epoch 25: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.025_.keras
#
# Epoch 25: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.025_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - dice_coef_loss: 0.8338 - loss: -0.8338 - val_dice_coef_loss: 0.7696 - val_loss: -0.7696
# Epoch 26/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.8319 - loss: -0.8319 - val_dice_coef_loss: 0.7704 - val_loss: -0.7704
# Epoch 27/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8375 - loss: -0.8375 - val_dice_coef_loss: 0.7690 - val_loss: -0.7690
# Epoch 28/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8410 - loss: -0.8410 - val_dice_coef_loss: 0.7820 - val_loss: -0.7820
# Epoch 29/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - dice_coef_loss: 0.8442 - loss: -0.8442 - val_dice_coef_loss: 0.7747 - val_loss: -0.7747
# Epoch 30/80
# 125/161 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - dice_coef_loss: 0.8398 - loss: -0.8398
# Epoch 30: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.030_.keras
#
# Epoch 30: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.030_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - dice_coef_loss: 0.8473 - loss: -0.8473 - val_dice_coef_loss: 0.7829 - val_loss: -0.7829
# Epoch 31/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8509 - loss: -0.8509 - val_dice_coef_loss: 0.7845 - val_loss: -0.7845
# Epoch 32/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8508 - loss: -0.8508 - val_dice_coef_loss: 0.7808 - val_loss: -0.7808
# Epoch 33/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8530 - loss: -0.8530 - val_dice_coef_loss: 0.7914 - val_loss: -0.7914
# Epoch 34/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - dice_coef_loss: 0.8577 - loss: -0.8577 - val_dice_coef_loss: 0.7870 - val_loss: -0.7870
# Epoch 35/80
# 120/161 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - dice_coef_loss: 0.8534 - loss: -0.8534
# Epoch 35: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.035_.keras
#
# Epoch 35: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.035_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - dice_coef_loss: 0.8582 - loss: -0.8582 - val_dice_coef_loss: 0.7936 - val_loss: -0.7936
# Epoch 36/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8554 - loss: -0.8554 - val_dice_coef_loss: 0.7893 - val_loss: -0.7893
# Epoch 37/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8566 - loss: -0.8566 - val_dice_coef_loss: 0.7960 - val_loss: -0.7960
# Epoch 38/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8632 - loss: -0.8632 - val_dice_coef_loss: 0.7946 - val_loss: -0.7946
# Epoch 39/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - dice_coef_loss: 0.8634 - loss: -0.8634 - val_dice_coef_loss: 0.7956 - val_loss: -0.7956
# Epoch 40/80
# 119/161 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - dice_coef_loss: 0.8632 - loss: -0.8632
# Epoch 40: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.040_.keras
#
# Epoch 40: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.040_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - dice_coef_loss: 0.8666 - loss: -0.8666 - val_dice_coef_loss: 0.8071 - val_loss: -0.8071
# Epoch 41/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8679 - loss: -0.8679 - val_dice_coef_loss: 0.7956 - val_loss: -0.7956
# Epoch 42/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8674 - loss: -0.8674 - val_dice_coef_loss: 0.8065 - val_loss: -0.8065
# Epoch 43/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8692 - loss: -0.8692 - val_dice_coef_loss: 0.8062 - val_loss: -0.8062
# Epoch 44/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - dice_coef_loss: 0.8717 - loss: -0.8717 - val_dice_coef_loss: 0.8133 - val_loss: -0.8133
# Epoch 45/80
# 113/161 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - dice_coef_loss: 0.8689 - loss: -0.8689
# Epoch 45: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.045_.keras
#
# Epoch 45: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.045_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - dice_coef_loss: 0.8744 - loss: -0.8744 - val_dice_coef_loss: 0.8035 - val_loss: -0.8035
# Epoch 46/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8737 - loss: -0.8737 - val_dice_coef_loss: 0.8054 - val_loss: -0.8054
# Epoch 47/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8732 - loss: -0.8732 - val_dice_coef_loss: 0.8130 - val_loss: -0.8130
# Epoch 48/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.8773 - loss: -0.8773 - val_dice_coef_loss: 0.8140 - val_loss: -0.8140
# Epoch 49/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - dice_coef_loss: 0.8790 - loss: -0.8790 - val_dice_coef_loss: 0.7818 - val_loss: -0.7818
# Epoch 50/80
# 105/161 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - dice_coef_loss: 0.8625 - loss: -0.8625
# Epoch 50: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.050_.keras
#
# Epoch 50: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.050_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - dice_coef_loss: 0.8757 - loss: -0.8757 - val_dice_coef_loss: 0.8093 - val_loss: -0.8093
# Epoch 51/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.8757 - loss: -0.8757 - val_dice_coef_loss: 0.7943 - val_loss: -0.7943
# Epoch 52/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8802 - loss: -0.8802 - val_dice_coef_loss: 0.8187 - val_loss: -0.8187
# Epoch 53/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8825 - loss: -0.8825 - val_dice_coef_loss: 0.8015 - val_loss: -0.8015
# Epoch 54/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - dice_coef_loss: 0.8856 - loss: -0.8856 - val_dice_coef_loss: 0.8209 - val_loss: -0.8209
# Epoch 55/80
# 101/161 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - dice_coef_loss: 0.8844 - loss: -0.8844
# Epoch 55: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.055_.keras
#
# Epoch 55: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.055_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8882 - loss: -0.8882 - val_dice_coef_loss: 0.8152 - val_loss: -0.8152
# Epoch 56/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8884 - loss: -0.8884 - val_dice_coef_loss: 0.8213 - val_loss: -0.8213
# Epoch 57/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8889 - loss: -0.8889 - val_dice_coef_loss: 0.8207 - val_loss: -0.8207
# Epoch 58/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8911 - loss: -0.8911 - val_dice_coef_loss: 0.8131 - val_loss: -0.8131
# Epoch 59/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - dice_coef_loss: 0.8884 - loss: -0.8884 - val_dice_coef_loss: 0.8103 - val_loss: -0.8103
# Epoch 60/80
#  99/161 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - dice_coef_loss: 0.8909 - loss: -0.8909
# Epoch 60: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.060_.keras
#
# Epoch 60: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.060_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - dice_coef_loss: 0.8945 - loss: -0.8945 - val_dice_coef_loss: 0.7726 - val_loss: -0.7726
# Epoch 61/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.8914 - loss: -0.8914 - val_dice_coef_loss: 0.8004 - val_loss: -0.8004
# Epoch 62/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8935 - loss: -0.8935 - val_dice_coef_loss: 0.7910 - val_loss: -0.7910
# Epoch 63/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - dice_coef_loss: 0.8951 - loss: -0.8951 - val_dice_coef_loss: 0.7679 - val_loss: -0.7679
# Epoch 64/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - dice_coef_loss: 0.8957 - loss: -0.8957 - val_dice_coef_loss: 0.8068 - val_loss: -0.8068
# Epoch 65/80
#  90/161 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - dice_coef_loss: 0.8761 - loss: -0.8761
# Epoch 65: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.065_.keras
#
# Epoch 65: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.065_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.8932 - loss: -0.8932 - val_dice_coef_loss: 0.7727 - val_loss: -0.7727
# Epoch 66/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.8996 - loss: -0.8996 - val_dice_coef_loss: 0.7685 - val_loss: -0.7685
# Epoch 67/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - dice_coef_loss: 0.8986 - loss: -0.8986 - val_dice_coef_loss: 0.8056 - val_loss: -0.8056
# Epoch 68/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.9014 - loss: -0.9014 - val_dice_coef_loss: 0.7998 - val_loss: -0.7998
# Epoch 69/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.9016 - loss: -0.9016 - val_dice_coef_loss: 0.8109 - val_loss: -0.8109
# Epoch 70/80
#  90/161 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - dice_coef_loss: 0.8981 - loss: -0.8981
# Epoch 70: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.070_.keras
#
# Epoch 70: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.070_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.9036 - loss: -0.9036 - val_dice_coef_loss: 0.8278 - val_loss: -0.8278
# Epoch 71/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - dice_coef_loss: 0.9056 - loss: -0.9056 - val_dice_coef_loss: 0.7587 - val_loss: -0.7587
# Epoch 72/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.9036 - loss: -0.9036 - val_dice_coef_loss: 0.8148 - val_loss: -0.8148
# Epoch 73/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.9077 - loss: -0.9077 - val_dice_coef_loss: 0.8278 - val_loss: -0.8278
# Epoch 74/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.9075 - loss: -0.9075 - val_dice_coef_loss: 0.8169 - val_loss: -0.8169
# Epoch 75/80
#  83/161 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - dice_coef_loss: 0.9057 - loss: -0.9057
# Epoch 75: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.075_.keras
#
# Epoch 75: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.075_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - dice_coef_loss: 0.9105 - loss: -0.9105 - val_dice_coef_loss: 0.7745 - val_loss: -0.7745
# Epoch 76/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - dice_coef_loss: 0.9088 - loss: -0.9088 - val_dice_coef_loss: 0.8235 - val_loss: -0.8235
# Epoch 77/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - dice_coef_loss: 0.9099 - loss: -0.9099 - val_dice_coef_loss: 0.7928 - val_loss: -0.7928
# Epoch 78/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - dice_coef_loss: 0.9125 - loss: -0.9125 - val_dice_coef_loss: 0.7687 - val_loss: -0.7687
# Epoch 79/80
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.9112 - loss: -0.9112 - val_dice_coef_loss: 0.8233 - val_loss: -0.8233
# Epoch 80/80
#  79/161 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - dice_coef_loss: 0.9096 - loss: -0.9096
# Epoch 80: saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.080_.keras
#
# Epoch 80: finished saving model to /content/TM11005_Unet/weights_bs2/w_epoch_.080_.keras
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - dice_coef_loss: 0.9145 - loss: -0.9145 - val_dice_coef_loss: 0.8032 - val_loss: -0.8032

# %% [markdown]
# ## Tutorial: How the model behaves with unseen data.
#
#    So far we have an idea how the model will perform with the training and validation
#    data. Additionally , we can use the graph to decide which parameters works
#    better for our validation data. Nevertheless, in real life situations we do
#    not have ground thruth. Therefore, to prove that our estimation is correct
#    we need to test our model with data that was not used at all to build our
#    network on the first place.
#
#    In the following example We will load a patient from the test set, make an
#    automatic segmentation with the network and compare the result with the
#    ground truth segmentation. According to out graph we should select a set of
#    weights obtained after epoch 72, from this we could expect a dice coeficent
#    around 0.8.

# %%
# First we load a prostate slice from the test set

im_arra= generate_batch_norm([x_test[6]])

# Then we  load a set of weights that theoretically will give us a good
# performance. The weights were save during the training process in the
# weights_new folder.

model.load_weights('/content/TM11005_Unet/weights_nw/w_epoch_.073_.keras')

# Now that the networks has loaded the weights from the desired epoc, we
# perfom a prediction on the slice.

mask_pred = model.predict(im_arra)

# The network requires the input to be (1x height x lengh x 1), however
# in order to visualize it , we need to  change it to a 2d array.
mask_pred = mask_pred [0,:,:,0]

# Then we load then ground thruth for that slice.
y_target = sitk.ReadImage(y_test[6])
y_target = sitk.GetArrayFromImage(y_target)


# We define a dice coefficent fuction :

def computeDice(reference, automatic):
    return 2*(np.sum(reference*automatic))/(np.sum(reference)+np.sum(automatic))

# Compute the dice and plot the images to compare
dice=str(computeDice(y_target,mask_pred))
print('dice = '+ str(computeDice(y_target,mask_pred)))


# Let's visualize the result on the test image
plt.figure(figsize=(16,10))
plt.subplot(1,3,1),plt.imshow(im_arra[0,:,:,0],cmap='gray'),plt.title('Unet_Prediction')
plt.subplot(1,3,1),plt.imshow(mask_pred,cmap=plt.cm.viridis,alpha=.3)

plt.subplot(1,3,2),plt.imshow(im_arra[0,:,:,0],cmap='gray'),plt.title('Ground_truth')
plt.subplot(1,3,2),plt.imshow(y_target,cmap=plt.cm.viridis,alpha=.3)

plt.subplot(1,3,3),plt.imshow(y_target,cmap='gray'),plt.title('Dice = '+dice)
plt.subplot(1,3,3),plt.imshow(mask_pred,cmap=plt.cm.viridis,alpha=.3)


# As you can see we achieve a "decent" result on one test example. Futhermore,
# small details should be corrected in a post-processing phase. Nevertheless,
# the network has learned some features to manage the segmentation in unseen
# data.
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b085e389120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step
# dice = 0.8461882272775083
# (<Axes: title={'center': 'Dice = 0.8461882272775083'}>,
#  <matplotlib.image.AxesImage at 0x7b085e3c46b0>)

# %% [markdown]
#  # Exercise 7: Visualize and quantify the learning process
#  Select a prostate slice from the test set and make a prediction with the
#   network using 4 sets of weights.
# - Select the weights using the loss function figure as reference, you should select4 weight files that theoretically should increase the performance of the network in increasing order (from the worst to the best).
#
# - Create a figure showing the  network prediction, overlapped on the the original image, including the weights file on the title.
#
# - Plot the ground truth overlayed on the original image
#
# - At the end your figure size will be 1x5, each plot showing the network prediction on the original image, identified with the weights title.
#
# - Comment your results by answering the following questions:
#
#   -Did the weight selection worked according to your graph?
#
#   -Can you see the network performance improving during the time?
#
#    -Did you get a worse result with the last set of weights? if yes, what     could be the reason behind this?

# %%
# write your code here
#Import necessary packages
import zipfile
import os

#Extract all the saved model weights from the zip file
with zipfile.ZipFile('/content/weights_lr0001.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/weights_lr0001')

#This is done to make the selection of the random test image reproducible
np.random.seed(6)

#Print the saved weights to see which weights there are
print(os.listdir('/content/TM11005_Unet/weights_nw_lr/'))

#Here a prostate slice is randomly selected from the test set and load it
test_index = np.random.randint(0, len(x_test))
im_arr = generate_batch_norm([x_test[test_index]])

#Then also the ground truth is loaded for that slice
y_target = sitk.ReadImage(y_test[test_index])
y_target = sitk.GetArrayFromImage(y_target)
np.squeeze(y_target)

#Choose 4 weights based on loss function when both validation and training loss decreases, so it was expected higher weights should perform better
weight_files = ['/content/TM11005_Unet/weights_nw_lr/w_epoch_.005_.keras','/content/TM11005_Unet/weights_nw_lr/w_epoch_.025_.keras','/content/TM11005_Unet/weights_nw_lr/w_epoch_.055_.keras','/content/TM11005_Unet/weights_nw_lr/w_epoch_.075_.keras']
weight_titles = ['Epoch 5','Epoch 25','Epoch 54','Epoch 73']

#Dice functie
def computeDice(reference, automatic):
    return 2 * np.sum(reference * automatic) / (np.sum(reference) + np.sum(automatic))

#Plotting
plt.figure(figsize=(20, 5))
#Plot first the ground truth
plt.subplot(1, 5, 1)
plt.imshow(im_arr[0, :, :, 0], cmap='gray')
plt.imshow(y_target, cmap='viridis', alpha=0.3)
plt.title('Ground truth')
plt.axis('off')


#Plot then the predictions with the 4 different weights
for i, weight_path in enumerate(weight_files):

    model_lr.load_weights(weight_path)

    #Predictions
    mask_pred = model_lr.predict(im_arr)
    # The network requires the input to be (1x height x lengh x 1), however
    # in order to visualize it , we need to  change it to a 2d array.
    mask_pred = mask_pred[0, :, :, 0]
    print(mask_pred.min(), mask_pred.max(), mask_pred.mean())

    #Calculate Dice
    dice = computeDice(y_target, mask_pred)

    #Plot predictions over the images
    plt.subplot(1, 5, i + 2)
    plt.imshow(im_arr[0, :, :, 0], cmap='gray')
    plt.imshow(mask_pred, cmap='viridis', alpha=0.5)
    plt.title(weight_titles[i] + '\nDice: ' + str(round(dice, 3)))
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ['w_epoch_.055_.keras', 'w_epoch_.050_.keras', 'w_epoch_.025_.keras', 'w_epoch_.075_.keras', 'w_epoch_.020_.keras', 'w_epoch_.080_.keras', 'w_epoch_.015_.keras', 'w_epoch_.010_.keras', 'w_epoch_.005_.keras', 'w_epoch_.045_.keras', 'w_epoch_.040_.keras', 'w_epoch_.035_.keras', 'w_epoch_.070_.keras', 'w_epoch_.060_.keras', 'w_epoch_.030_.keras', 'w_epoch_.065_.keras']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1.625345e-33 0.5118912 0.2137
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 0.0 0.55462205 0.181063
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 0.0 0.61275405 0.17424181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 0.0 0.64901054 0.17250419
